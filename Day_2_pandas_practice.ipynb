# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
house_df = pd.read_csv('Housing.csv')

# %%
house_df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
for i in house_df['guestroom']:
  print(i)

# %%
house_df['guestroom'] = house_df['guestroom'].apply(lambda x: 1 if x == 'yes' else 0)

# %%
house_df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad  guestroom  \
# 0    13300000  7420         4          2        3      yes          0
# 1    12250000  8960         4          4        4      yes          0
# 2    12250000  9960         3          2        2      yes          0
# 3    12215000  7500         4          2        2      yes          0
# 4    11410000  7420         4          1        2      yes          1
# ..        ...   ...       ...        ...      ...      ...        ...
# 540   1820000  3000         2          1        1      yes          0
# 541   1767150  2400         3          1        1       no          0
# 542   1750000  3620         2          1        1      yes          0
# 543   1750000  2910         3          1        1       no          0
# 544   1750000  3850         3          1        2      yes          0
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
house_df['total_rooms'] = house_df['bedrooms'] + house_df['bathrooms'] + house_df['guestroom']

# %%
house_df['total_rooms']
# Out:
# 0      6
# 1      8
# 2      5
# 3      6
# 4      6
#       ..
# 540    3
# 541    4
# 542    3
# 543    4
# 544    4
# Name: total_rooms, Length: 545, dtype: int64

# %%
house_df['area meters squared'] = house_df['area']*0.09290304

# %%
house_df['area meters squared']
# Out:
# 0      689.340557
# 1      832.411238
# 2      925.314278
# 3      696.772800
# 4      689.340557
#           ...
# 540    278.709120
# 541    222.967296
# 542    336.309005
# 543    270.347846
# 544    357.676704
# Name: area meters squared, Length: 545, dtype: float64

# %% [markdown]
# We can do vectorized operations in base-python as well.

# %%
test_list = ['yes', 'no', 'no', 'no', 'yes','yes','yes']

# %%
list(map(lambda x: 1 if x == 'yes' else 0,test_list))
# Out:
# [1, 0, 0, 0, 1, 1, 1]

# %%
def convert_to_dummy(x):
  if x == 'yes':
    x = 1
  else:
    x = 0
  return x

# %%
list(map(convert_to_dummy,test_list))
# Out:
# [1, 0, 0, 0, 1, 1, 1]

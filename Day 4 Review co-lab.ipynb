# %% [markdown]
# Python Offers a variety of basic data types that we can do some basic operations on. Tinkering and experimenting with data comes highly recommended

# %%
#strings
my_string = 'fdfsdfsdfsdfsfd'
another_string = 'some string'
#ints
my_int = 4
another_int = 347
#floats
my_float = 23.17
another_float = 71.9
#booleans
my_bool = True
another_bool = False
yet_another_bool = (4 == 6)

# %% [markdown]
# We can see the variety of built in method's to use on Strings:

# %%
# Length of the string
#print(len(my_string))

# Accessing individual characters using indexing
#print(my_string[0])     # Output: 'f'
#print(another_string[5])  # Output: 's'

# Slicing a string
#print(my_string[2:5])     # Output: 'fds'
#print(another_string[3:])  # Output: 'e string'

# Concatenating strings
#concatenated = my_string + another_string
#print(concatenated)       # Output: 'fdfsdfsdfsdfsfdsome string'
#print('abc'+'def')
# Converting to uppercase or lowercase
#print(my_string.upper())    # Output: 'FDFSDFSDFSDFSFD'
#print('ASAFD!&'.lower())  #
#print("doijhgjh".title())
# Checking if a string starts or ends with a specific substring
#print(my_string.startswith('z'))   # Output: True
#my_string[0] == 'z'
#print(another_string.endswith('ing'))  # Output: True
#print('abcde'.endswith('cde'))
# Splitting a string into a list of substrings
#split_string = another_string.split('m')
#print(split_string)      # Output: ['some', 'string']

# Replacing substrings
replaced_string = my_string.replace('fd', 'xyz')
print(replaced_string)   # Output: 'xyzsdfsdfsdfsxyzsfd'

# Finding the index of a substring
print(another_string.index('r'))   # Output: 5

# Counting occurrences of a substring
print(my_string.count('df'))   # Output: 2
# Out:
# Doijhgjh
# xyzfsdfsdfsdfsxyz
# 7
# 4

# %%
some_string = 'dvgddgdfg'
letters_dict = { 'a': 'A','b':"B",'c':"C",'d':'D'}
new_string = letters_dict[some_string[0]] + some_string[1:]
print(new_string)
# Out:
# Dvgddgdfg

# %% [markdown]
# This method for counting occurences of a substring allows for a "rules-based" sentiment analysis of text.
# Incidently this allows us to make good use of functions and if/else logic.

# %%
def sentiment_detection(sentence):
  positive = False
  negative = False
  for i in ('happy', 'sunny', 'positive','triumphant','optimistic','wonderful'):
    if sentence.count(i) > 0:
      positive = True
      break
  for i in ('sad','terrible','frightening','rainy','scary'):
    if sentence.count(i) > 0:
      negative = True
      break
  if positive == negative == False:
    return "neutral"
  elif positive == True != negative:
    return "positive"
  elif negative == True != positive:
    return 'negative'
  else:
    return "mixed"

# %%
sentiment_detection("It was rainy yesterday and people stayed home")
# Out:
# 'negative'

# %%
def sentiment_detection(sentence):
  positive = False
  negative = False
  for i in ('happy', 'sunny', 'positive','triumphant','optimistic','wonderful'):
    if i in sentence:
      positive = True
      break
  for i in ('sad','terrible','frightening','rainy','scary'):
    if i in sentence:
      negative = True
      break
  if positive == negative == False:
    return "neutral"
  elif positive == True != negative:
    return "positive"
  elif negative == True != positive:
    return 'negative'
  else:
    return "mixed"

# %%
sentiment_detection('They went for a walk and it was rainy but it was wonderful')
# Out:
# 'mixed'

# %%
('store' in 'they are going to the store')
# Out:
# True

# %%
(True+True)**(True+True+True)
# Out:
# 8

# %% [markdown]
# On the other hand booleans do not behave this way in Pandas...

# %%
import pandas as pd
df = pd.DataFrame({'bool 1':[True, False, True, True],'bool 2': [False,False,True,True]})
df['bool 3'] = df['bool 1'] + df['bool 2']
df
# Out:
#    bool 1  bool 2  bool 3
# 0    True   False    True
# 1   False   False   False
# 2    True    True    True
# 3    True    True    True

# %%
sentiment_detection('jerry went to the rainy park and it was wonderful')
# Out:
# 'mixed'

# %%
sentiment_detection("It is rainy")
# Out:
# 'negative'

# %%
sentiment_detection("It is sunny")
# Out:
# 'positive'

# %% [markdown]
# What if we want the sentiment detection to put a NUMBER on the positive score and a NUMBER on the negative score, and return a score for each?

# %%
def sentiment_detection(sentence):
  positive = 0
  negative = 0
  for i in ('happy', 'sunny', 'positive','triumphant','optimistic','wonderful'):
    positive = positive + sentence.count(i)
  for i in ('sad','terrible','frightening','rainy','scary'):
    negative = negative + sentence.count(i)
  return {'positive':positive,'negative':negative}

# %%
sentiment_detection("They went to the park and it was sunny, then it was rainy, but all in all it was a wonderful time")
# Out:
# {'positive': 2, 'negative': 1}

# %%
sentiment_detection("sunny sunny sunny rainy sad scary wonderful")
# Out:
# {'positive': 4, 'negative': 3}

# %% [markdown]
# We can run different methods on Ints

# %%
# Converting an integer to a string
#print((str(my_int)))       # Output: '4'
#print(str(another_int))  # Output: '347'

# Finding the absolute value
#print(abs(-5))           # Output: 5
#print(abs(-10.5))        # Output: 10.5

# Performing arithmetic operations
#print(my_int + another_int)  # Output: 351
#print(my_int * another_int)  # Output: 1388
#print(my_int / another_int)  # Output: 0.011507965444679398
#print(4 / 2)
# Checking if an integer is even or odd
#print(my_int % 2 == 0)       # Output: True
#print(another_int % 2 == 0)  # Output: False
#print(17%3)
# Checking if an integer is positive, negative, or zero
#print(my_int > 0)            # Output: True
#print(another_int < 0)       # Output: False
#print(my_int == 0)           # Output: False

# Raising an integer to a power
#print(my_int**2)           # Output: 16
#print(another_int ** 3)      # Output: 43046723
#print(my_int**(1/2))
#Checking if an integer is divisible by another integer
#print(another_int % 7 == 0)  # Output: True
(3**(3.0))
# Out:
# 27.0

# %%
22%7
# Out:
# 1

# %% [markdown]
# We can run different methods on Floats

# %%
# Rounding a float to a specified number of decimal places
#print(round(my_float, 2))              # Output: 23.2
#print(round(another_float, 0))         # Output: 72.0
#print(round(45.5, 0))
# Getting the fractional and integer parts of a float
#print((10.0).is_integer())           # Output: True
#print((4.5).as_integer_ratio())     # Output: (9,2)
#print(another_float.as_integer_ratio())# Output: (2529756353187021, 35184372088832)


# Converting a float to an integer (rounded towards zero)
#print(int(my_float))                   # Output: 23
#print(int(another_float))              # Output: 71
#print(int(73.99999))

# Getting the absolute value of a float
#print(abs(-my_float))                   # Output: 23.17
#print(abs(another_float))              # Output: 71.9

# Converting a float to a string with specific formatting
#print(format(my_float, '.2f'))         # Output: '23.17'
#print(format(another_float, '.2f'))    # Output: '71.9'

# Performing mathematical functions on floats
import math
#print(math.sqrt(4))             # Output: 4.812618965552178
#print(math.sin(3.14/2))         # Output: -0.48514693710658093
#print(math.exp(1))              # Output: 1
# Out:
# 2.718281828459045

# %% [markdown]
# There are a variety of methods and codes we can run with booleans that have surprising results

# %%
# Boolean literals
#print(True)      # Output: True
#print(False)     # Output: False

# Boolean comparisons
#print(2 > 1)     # Output: True
#print(3 == 3.0)  # Output: True
#print(5 != 5.0000)    # Output: False

# Boolean logical operators
#print(True and False)     # Output: False
#print(True or False or False or False or False or False or False)      # Output: True
#print(not True)           # Output: False

#if (2 > 3) or (2>1) or ('a'=='b') or ('c'=='d'):
#  print(True)

# Converting a boolean to an integer or string
#print(int(True))          # Output: 1
#print(int(False))         # Output: 0

#Math with Booleans
#print(True+True*False)
#print(True+True)
#print(True*3)
#print(True*False)

# Boolean operations with lists
#my_list = [1, 2, 3]
#print(2 in my_list)       # Output: True
#print(4 in my_list)       # Output: False


# Boolean operations with sets
my_set = {1, 2, 3}
#print(2 in my_set)        # Output: True
#print(4 in my_set)        # Output: False
# Out:
# 0

# %% [markdown]
# There is an efficient alternative to for-loops called comprehensions. The logic is very similar from a coding perspective, some consider the comprehensions more readable, and often times they may run faster.

# %%
#for loop
numbers = [1, 2, 3, 4, 5]
squared_numbers = []
for num in numbers:
    squared_numbers.append(num ** 2)
print(squared_numbers)  # Output: [1, 4, 9, 16, 25]
# Out:
# [1, 4, 9, 16, 25]

# %%
#comprehension
numbers = [1, 2, 3, 4, 5]
squared_numbers = [number**2 for number in numbers] # [(operation on object) for object in iterable]
print(squared_numbers)  # Output: [1, 4, 9, 16, 25]
# Out:
# [1, 4, 9, 16, 25]

# %%
list(map(lambda x: x**2, numbers))
# Out:
# [1, 4, 9, 16, 25]

# %%
#for loop
numbers = [1, 2, 3, 4, 5]
even_numbers = []
for num in numbers:
    if num % 2 == 0:
        even_numbers.append(num)
print(even_numbers)  # Output: [2, 4]
# Out:
# [2, 4]

# %%
#comprehension
numbers = [1, 2, 3, 4, 5]
even_numbers = [num for num in numbers if num % 2 == 0] # object for object in iterable if the object meets some condition
print(even_numbers)  # Output: [2, 4]
# Out:
# [2, 4]

# %%
#for loop
names = ['Alice', 'Bob', 'Charlie']
uppercase_names = []
for name in names:
    uppercase_names.append(name.upper())
print(uppercase_names)  # Output: ['ALICE', 'BOB', 'CHARLIE']
# Out:
# ['ALICE', 'BOB', 'CHARLIE']

# %%
#comprehension
names = ['Alice', 'Bob', 'Charlie']
uppercase_names = [name.upper() for name in names]
print((uppercase_names))  # Output: ['ALICE', 'BOB', 'CHARLIE']
# Out:
# ['ALICE', 'BOB', 'CHARLIE']

# %%
uppercase_names = list(map(lambda x: x.upper(),names))
uppercase_names
# Out:
# ['ALICE', 'BOB', 'CHARLIE']

# %% [markdown]
# As seen previously NumPy provides efficient ways for doing opperations on data that would otherwise be difficult. One of the biggest fundamental advantages of NumPy is how it '*vectorizes*' operations. Such operations don't require a lengthy process of iterating over a data-structure, but instead take advantage of low-level code where an operation may be applied to every element in a data-structure in parallel.

# %%
# Using for-loops

a = [1, 2, 3]
b = [4, 5, 6]
result = []
for i in range(len(a)):
    result.append(a[i] * b[i])
print(result)  # Output: [4, 10, 18]
# Out:
# [4, 10, 18]

# %%
# Using NumPy arrays
import numpy as np

a = np.array([1, 2, 3])
b = np.array([4, 5, 6])
result = a * b
print(result)  # Output: [4 10 18]
# Out:
# [ 4 10 18]

# %%
np.dot(a,b)
# Out:
# 32

# %%
# Using for-loops
import numpy as np

a = [1, 2, 3, 4, 5]
sum_result = 0
for num in a:
    sum_result += num
print(sum_result)  # Output: 15
# Out:
# 15

# %%
# Using NumPy arrays
import numpy as np

a = np.array([1, 2, 3, 4, 5])
sum_result = np.sum(a)
print(sum_result)  # Output: 15
# Out:
# 15

# %%
# Using for-loops
import numpy as np

a = [1, 2, 3, 4, 5]
result = []
for num in a:
    result.append(num ** 2)
print(result)  # Output: [1, 4, 9, 16, 25]
# Out:
# [1, 4, 9, 16, 25]

# %%
# Using NumPy arrays
import numpy as np

a = np.array([1, 2, 3, 4, 5])
result = np.square(a)
print(result)  # Output: [ 1  4  9 16 25]
# Out:
# [ 1  4  9 16 25]

# %%
# Using a for-loop
a = [1, 2, 3, 4, 5]
b = [6, 7, 8, 9, 10]
result = []
for i in range(len(a)):
    result.append(a[i] + b[i])
print(result)
# Out:
# [7, 9, 11, 13, 15]

# %%
# Using NumPy arrays
import numpy as np
a = np.array([1, 2, 3, 4, 5])
b = np.array([6, 7, 8, 9, 10])
result = a + b
print(result)
# Out:
# [ 7  9 11 13 15]

# %%
# Using a for-loop
def multiply_list_by_constant(lst, constant):
    result = []
    for num in lst:
        result.append(num * constant)
    return result

numbers = [1, 2, 3, 4, 5]
constant = 2
result = multiply_list_by_constant(numbers, constant)
print(result)  # Output: [2, 4, 6, 8, 10]
# Out:
# [2, 4, 6, 8, 10]

# %%
# Using NumPy arrays
import numpy as np

numbers = np.array([1, 2, 3, 4, 5])
constant = 2
result = numbers * constant
print(result)  # Output: [2 4 6 8 10]
# Out:
# [ 2  4  6  8 10]

# %% [markdown]
# Previously we saw a function using for-loops to do a rules-based sentiment analysis. Let's see how it can be optimized using comprehensions.

# %%
def sentiment_detection(sentence):
    positive_words = ('happy', 'sunny', 'positive', 'triumphant', 'optimistic', 'wonderful')
    negative_words = ('sad', 'terrible', 'frightening', 'rainy', 'scary')

    positive = any(sentence.count(i) > 0 for i in positive_words)
    negative = any(sentence.count(i) > 0 for i in negative_words)
    if positive == negative == False:
      return "neutral"
    elif positive and not negative:
      return "positive"
    elif negative and not positive:
      return 'negative'
    else:
      return "mixed"


'''
    if positive == negative == False:
        return "neutral"
    elif positive != negative:
        return "positive" if positive else "negative"
    else:
        return "mixed"
'''

# %%
any(['sfsadff',False])
# Out:
# True

# %%
positive_words = ('happy', 'sunny', 'positive', 'triumphant', 'optimistic', 'wonderful')
sentence = 'I am happy'
any(i in sentence for i in positive_words)
#any([True])
# Out:
# True

# %%
#an overview of bringing in data and working with it

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
country_df = pd.read_csv("/content/Countries_of_the_world_1970 - imputed_international_data_70 (2).csv")

# %%
country_df.head()
# Out:
#         Entity  indiv_libs_vdem_owid  electdem_vdem_owid  libdem_vdem_owid  \
# 0  Afghanistan                 0.266               0.160             0.104
# 1      Albania                 0.006               0.173             0.055
# 2      Algeria                 0.428               0.084             0.065
# 3       Angola                 0.024               0.010             0.035
# 4    Argentina                 0.354               0.105             0.086
#
#    Countries  Economic.Freedom.Summary.Index  Government.consumption  \
# 0        NaN                        5.506573                6.393604
# 1    Albania                        3.713222                3.170575
# 2    Algeria                        4.680000                5.540000
# 3     Angola                        4.547754                6.109553
# 4  Argentina                        5.980000                7.930000
#
#    Transfers.and.subsidies  Government.investment  State.ownership.of.assets  \
# 0                 8.740967               5.519734                   5.025106
# 1                 8.262926              -0.627520                   0.180000
# 2                 9.322154               7.320000                   2.490000
# 3                 8.385527               4.949296                   3.180000
# 4                 8.006018               8.187808                   6.150000
#
#    ...  Centralized.collective.bargaining  Hours.Regulations  Conscription  \
# 0  ...                           5.897546           5.932564      2.392234
# 1  ...                           4.220652           4.846848      0.000000
# 2  ...                           5.540452           6.185718      3.000000
# 3  ...                           4.641346           5.671838      0.536243
# 4  ...                           5.180000           5.720000      0.000000
#
#    Labor.market.regulations  Impartial.Public.Administration  Regulation  \
# 0                  4.700103                         4.887146    4.776903
# 1                  4.215714                         1.750000    3.230021
# 2                  4.572435                         3.910000    3.630000
# 3                  3.955813                         2.370000    3.778725
# 4                  3.630000                         2.420000    5.310000
#
#         alliance  regimenarrowcat        Regime_type  id
# 0  not a US ally              8.0           Monarchy   1
# 1  not a US ally              4.0  Single-party rule   2
# 2  not a US ally              7.0      Military rule   3
# 3  not a US ally              NaN            unknown   4
# 4        US ally              7.0      Military rule   5
#
# [5 rows x 43 columns]

# %%
#creating a new column
country_df['indiv_libs_percent'] = country_df['indiv_libs_vdem_owid']*100

# %%
country_df.head()
# Out:
#         Entity  indiv_libs_vdem_owid  electdem_vdem_owid  libdem_vdem_owid  \
# 0  Afghanistan                 0.266               0.160             0.104
# 1      Albania                 0.006               0.173             0.055
# 2      Algeria                 0.428               0.084             0.065
# 3       Angola                 0.024               0.010             0.035
# 4    Argentina                 0.354               0.105             0.086
#
#    Countries  Economic.Freedom.Summary.Index  Government.consumption  \
# 0        NaN                        5.506573                6.393604
# 1    Albania                        3.713222                3.170575
# 2    Algeria                        4.680000                5.540000
# 3     Angola                        4.547754                6.109553
# 4  Argentina                        5.980000                7.930000
#
#    Transfers.and.subsidies  Government.investment  State.ownership.of.assets  \
# 0                 8.740967               5.519734                   5.025106
# 1                 8.262926              -0.627520                   0.180000
# 2                 9.322154               7.320000                   2.490000
# 3                 8.385527               4.949296                   3.180000
# 4                 8.006018               8.187808                   6.150000
#
#    ...  Hours.Regulations  Conscription  Labor.market.regulations  \
# 0  ...           5.932564      2.392234                  4.700103
# 1  ...           4.846848      0.000000                  4.215714
# 2  ...           6.185718      3.000000                  4.572435
# 3  ...           5.671838      0.536243                  3.955813
# 4  ...           5.720000      0.000000                  3.630000
#
#    Impartial.Public.Administration  Regulation       alliance  \
# 0                         4.887146    4.776903  not a US ally
# 1                         1.750000    3.230021  not a US ally
# 2                         3.910000    3.630000  not a US ally
# 3                         2.370000    3.778725  not a US ally
# 4                         2.420000    5.310000        US ally
#
#    regimenarrowcat        Regime_type  id  indiv_libs_percent
# 0              8.0           Monarchy   1                26.6
# 1              4.0  Single-party rule   2                 0.6
# 2              7.0      Military rule   3                42.8
# 3              NaN            unknown   4                 2.4
# 4              7.0      Military rule   5                35.4
#
# [5 rows x 44 columns]

# %%
country_df["sum index"] = country_df["indiv_libs_vdem_owid"] + country_df["electdem_vdem_owid"] + country_df["libdem_vdem_owid"]

# %%
country_df["sum index"]
# Out:
# 0      0.530
# 1      0.234
# 2      0.577
# 3      0.069
# 4      0.545
#        ...
# 177      NaN
# 178      NaN
# 179      NaN
# 180      NaN
# 181      NaN
# Name: sum index, Length: 182, dtype: float64

# %% [markdown]
# Now a review of Pandas and it's built in techniques for data analysis

# %%
import pandas as pd
import numpy as np

# Creating two DataFrames
df1 = pd.DataFrame({'ID': [1, 2, 3, 4],
                    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
                    'Age': [25, 30, 35, 40]})

df2 = pd.DataFrame({'person_ID': [1, 2, 3, 5],
                    'Salary': [50000, 60000, 70000, 80000]})

df2 = df2.rename(columns={"person_ID": "ID"})


#CHALLENGE Next we will think of a way to do the merge so we don't lose any data.
# Merging DataFrames
merged_df = pd.merge(df1, df2, on='ID', how='left')
print(merged_df)
# Output:
#    ID     Name  Age   Salary
# 0   1    Alice   25  50000.0
# 1   2      Bob   30  60000.0
# 2   3  Charlie   35  70000.0
# 3   4    David   40      NaN
# Out:
#    ID     Name  Age   Salary
# 0   1    Alice   25  50000.0
# 1   2      Bob   30  60000.0
# 2   3  Charlie   35  70000.0
# 3   4    David   40      NaN

# %%
df2
# Out:
#    ID  Salary
# 0   1   50000
# 1   2   60000
# 2   3   70000
# 3   5   80000

# %%
#let's merge them so no data is lost
merged_df_outer = pd.merge(df1, df2, on='ID', how='outer')
print(merged_df_outer)
# Out:
#    ID     Name   Age   Salary
# 0   1    Alice  25.0  50000.0
# 1   2      Bob  30.0  60000.0
# 2   3  Charlie  35.0  70000.0
# 3   4    David  40.0      NaN
# 4   5      NaN   NaN  80000.0

# %%
# Creating a new column using a lambda function

def convert(x):
  if x < 30:
    return 'Youth'
  else:
     return 'Adult'

merged_df['Age_Category'] = merged_df['Age'].apply(convert)
print(merged_df)
# Output:
#    ID     Name  Age   Salary Age_Category
# 0   1    Alice   25  50000.0        Youth
# 1   2      Bob   30  60000.0        Adult
# 2   3  Charlie   35  70000.0        Adult
# 3   4    David   40      NaN        Adult

# Creating a new column using a NumPy function
merged_df['Age_Squared'] = np.square(merged_df['Age'])
print(merged_df)
# Output:
#    ID     Name  Age   Salary Age_Category  Age_Squared
# 0   1    Alice   25  50000.0        Youth          625
# 1   2      Bob   30  60000.0        Adult          900
# 2   3  Charlie   35  70000.0        Adult         1225
# 3   4    David   40      NaN        Adult         1600
# Out:
#    ID     Name  Age   Salary Age_Category
# 0   1    Alice   25  50000.0        Youth
# 1   2      Bob   30  60000.0        Adult
# 2   3  Charlie   35  70000.0        Adult
# 3   4    David   40      NaN        Adult
#    ID     Name  Age   Salary Age_Category  Age_Squared
# 0   1    Alice   25  50000.0        Youth          625
# 1   2      Bob   30  60000.0        Adult          900
# 2   3  Charlie   35  70000.0        Adult         1225
# 3   4    David   40      NaN        Adult         1600

# %%
merged_df_outer['Age_Category'] = merged_df_outer['Age'].apply(lambda x: 'Youth' if x < 30 else 'Adult')
print(merged_df_outer)
# Out:
#    ID     Name   Age   Salary Age_Category
# 0   1    Alice  25.0  50000.0        Youth
# 1   2      Bob  30.0  60000.0        Adult
# 2   3  Charlie  35.0  70000.0        Adult
# 3   4    David  40.0      NaN        Adult
# 4   5      NaN   NaN  80000.0        Adult

# %%
merged_df_outer['Age_Category'] = merged_df_outer['Age'].apply(lambda x: 'Youth' if x < 30 elif 'Adult' x >= 30 else np.nan)
print(merged_df_outer)
# Out:
#   File "<ipython-input-45-e59c627e2e2d>", line 1
#     merged_df_outer['Age_Category'] = merged_df_outer['Age'].apply(lambda x: 'Youth' if x < 30 elif 'Adult' x >= 30 else np.nan)
#                                                                              ^
# SyntaxError: expected 'else' after 'if' expression

# %% [markdown]
# NumPy offers some amazing functions for handling different conditions

# %%
data = {'A': [1, 2, 3, 4, 5], 'B': [10, 20, 30, 40, 50]}
df = pd.DataFrame(data)

# Define the conditions
conditions = [
    df['A'] < 3,
    df['A'] >= 3,
]

# Define the functions corresponding to each condition
def function1(x):
    return x * 2

def function2(x):
    return x + 5

# Vectorize the functions
vectorized_function1 = np.vectorize(function1)
vectorized_function2 = np.vectorize(function2)

# Apply the functions based on the conditions and create the new column
df['C'] = np.select(conditions, [vectorized_function1(df['A']), vectorized_function2(df['B'])], default=np.nan)

# Display the updated DataFrame
print(df)
# Out:
#    A   B     C
# 0  1  10   2.0
# 1  2  20   4.0
# 2  3  30  35.0
# 3  4  40  45.0
# 4  5  50  55.0

# %%
conditions = [
    merged_df_outer['Age'] < 30,
    merged_df_outer['Age'] >= 30
]

merged_df_outer['Age_Category'] = np.select(conditions, ['Youth', 'Adult'], default=np.nan)

# Display the updated DataFrame
print(merged_df_outer)
# Out:
#    ID     Name   Age   Salary Age_Category
# 0   1    Alice  25.0  50000.0        Youth
# 1   2      Bob  30.0  60000.0        Adult
# 2   3  Charlie  35.0  70000.0        Adult
# 3   4    David  40.0      NaN        Adult
# 4   5      NaN   NaN  80000.0          nan

# %%
def convert(x):
  if x < 30:
    return 'Youth'
  elif x >= 30:
    return 'Adult'
  else:
     return np.nan

# %%
merged_df_outer['Age_Category'] = merged_df_outer['Age'].apply(convert)
print(merged_df_outer)
# Out:
#    ID     Name   Age   Salary Age_Category
# 0   1    Alice  25.0  50000.0        Youth
# 1   2      Bob  30.0  60000.0        Adult
# 2   3  Charlie  35.0  70000.0        Adult
# 3   4    David  40.0      NaN        Adult
# 4   5      NaN   NaN  80000.0          NaN

# %%
data = {'A': [1, 2, 3, 4, 5], 'B': [10, 20, 30, 40, 50]}
df = pd.DataFrame(data)
df
# Define the conditions
conditions = [
    df['A'] < 3,
    df['A'] >= 3
]

# Define the functions corresponding to each condition
def function1(df):
    return df['A'] * 2 + df['B']

def function2(df):
    return df['A'] + df['B'] * 2

# Apply the functions based on the conditions and create the new column
df['C'] = np.select(conditions, [function1(df), function2(df)], default=np.nan)

# Display the updated DataFrame
print(df)
# Out:
#    A   B      C
# 0  1  10   12.0
# 1  2  20   24.0
# 2  3  30   63.0
# 3  4  40   84.0
# 4  5  50  105.0

# %% [markdown]
# Just like SQL, pandas also offers the option to group/aggregate data

# %%
import pandas as pd

# Creating a sample DataFrame
data = {
    'Product': ['A', 'B', 'C', 'A', 'B', 'C'],
    'Category': ['X', 'Y', 'Z', 'X', 'Y', 'Z'],
    'Sales': [100, 150, 200, 250, 300, 350],
    'revenue': [60,70,50,80,40,90]
}
df = pd.DataFrame(data)

# Grouping the DataFrame by 'Category' and calculating the total sales
grouped_df = df.groupby('Category')['Sales'].mean()

print(grouped_df)
# Out:
# Category
# X    175.0
# Y    225.0
# Z    275.0
# Name: Sales, dtype: float64

# %%
df_window = pd.merge(df, grouped_df, on='Category', how='left')
df_window.rename(columns={"Sales_y": "sales_category_average"})
df_window
# Out:
#   Product Category  Sales_x  revenue  Sales_y
# 0       A        X      100       60    175.0
# 1       B        Y      150       70    225.0
# 2       C        Z      200       50    275.0
# 3       A        X      250       80    175.0
# 4       B        Y      300       40    225.0
# 5       C        Z      350       90    275.0

# %%
df_window
# Out:
#   Product Category  Sales_x  revenue  sales_category_average
# 0       A        X      100       60                   175.0
# 1       B        Y      150       70                   225.0
# 2       C        Z      200       50                   275.0
# 3       A        X      250       80                   175.0
# 4       B        Y      300       40                   225.0
# 5       C        Z      350       90                   275.0

# %%
type(grouped_df)
# Out:
# pandas.core.series.Series

# %%
grouped_df = pd.DataFrame(grouped_df)
grouped_df
# Out:
#           Sales
# Category
# X         175.0
# Y         225.0
# Z         275.0

# %%
2 >= 2
# Out:
# True

# %% [markdown]
# https://www.hackerrank.com/challenges/py-if-else/problem?isFullScreen=true

# %%
if n%2 != 0 or (n >= 6 and n <= 20):
    print('Weird')
else:
    print('Not Weird')
